# %% [markdown]
# <a href="https://colab.research.google.com/github/vikram4690/MRI-image-denoising-model-using-Autoencoder/blob/main/Image_Denoising_using_Autoencoder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import os
from keras.preprocessing import image
import matplotlib.pyplot as plt
from keras.models import Sequential, Model
from keras.layers import Dense, Conv2D, MaxPooling2D,MaxPool2D ,UpSampling2D, Flatten, Input
from keras.optimizers import SGD, Adam, Adadelta, Adagrad
from keras import backend as K
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
import os
import cv2
from math import log10,sqrt
from PIL import Image
from tensorflow.keras.preprocessing.image import img_to_array,load_img

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
train_images=sorted(os.listdir('drive/My Drive/vikii/dc'))
print(train_images)
# Out:
# ['137covid_patient103_SR_2_IM00036.png', '137covid_patient103_SR_2_IM00037.png', '137covid_patient103_SR_2_IM00038.png', '137covid_patient103_SR_3_IM00017.png', '137covid_patient103_SR_3_IM00018.png', '137covid_patient103_SR_3_IM00019.png', '137covid_patient103_SR_3_IM00020.png', '137covid_patient103_SR_3_IM00021.png', '137covid_patient103_SR_3_IM00026.png', '137covid_patient103_SR_4_IM00016.png', '137covid_patient103_SR_4_IM00017.png', '137covid_patient103_SR_4_IM00018.png', '137covid_patient103_SR_4_IM00019.png', '137covid_patient103_SR_4_IM00020.png', '137covid_patient105_SR_2_IM00010.png', '137covid_patient105_SR_2_IM00011.png', '137covid_patient105_SR_2_IM00012.png', '137covid_patient105_SR_2_IM00014.png', '137covid_patient105_SR_2_IM00015.png', '137covid_patient105_SR_2_IM00019.png', '137covid_patient105_SR_2_IM00020.png', '137covid_patient105_SR_2_IM00021.png', '137covid_patient105_SR_2_IM00023.png', '137covid_patient105_SR_2_IM00024.png', '137covid_patient105_SR_2_IM00025.png', '137covid_patient105_SR_2_IM00026.png', '137covid_patient105_SR_2_IM00027.png', '137covid_patient105_SR_3_IM00010.png', '137covid_patient105_SR_3_IM00011.png', '137covid_patient105_SR_3_IM00013.png', '137covid_patient105_SR_3_IM00014.png', '137covid_patient105_SR_3_IM00016.png', '137covid_patient105_SR_3_IM00019.png', '137covid_patient105_SR_3_IM00020.png', '137covid_patient105_SR_3_IM00022.png', '137covid_patient105_SR_3_IM00023.png', '137covid_patient105_SR_3_IM00026.png', '137covid_patient105_SR_4_IM00050.png', '137covid_patient105_SR_4_IM00051.png', '137covid_patient105_SR_4_IM00052.png', '137covid_patient105_SR_4_IM00054.png', '137covid_patient105_SR_4_IM00055.png', '137covid_patient105_SR_4_IM00056.png', '137covid_patient105_SR_4_IM00075.png', '137covid_patient105_SR_4_IM00076.png', '137covid_patient105_SR_4_IM00077.png', '137covid_patient105_SR_4_IM00098.png', '137covid_patient105_SR_4_IM00099.png', '137covid_patient105_SR_4_IM00100.png', '137covid_patient105_SR_4_IM00101.png', '137covid_patient105_SR_4_IM00103.png', '137covid_patient105_SR_4_IM00121.png', '137covid_patient105_SR_4_IM00122.png', '137covid_patient10_SR_2_IM00012.png', '137covid_patient10_SR_2_IM00013.png', '137covid_patient10_SR_2_IM00014.png', '137covid_patient10_SR_2_IM00015.png', '137covid_patient10_SR_2_IM00016.png', '137covid_patient10_SR_2_IM00017.png', '137covid_patient10_SR_2_IM00018.png', '137covid_patient10_SR_2_IM00020.png', '137covid_patient10_SR_2_IM00022.png', '137covid_patient10_SR_2_IM00024.png', '137covid_patient10_SR_2_IM00025.png', '137covid_patient10_SR_2_IM00026.png', '137covid_patient10_SR_2_IM00027.png', '137covid_patient10_SR_2_IM00028.png', '137covid_patient10_SR_3_IM00011.png', '137covid_patient10_SR_3_IM00012.png', '137covid_patient10_SR_3_IM00013.png', '137covid_patient10_SR_3_IM00014.png', '137covid_patient10_SR_3_IM00015.png', '137covid_patient10_SR_3_IM00016.png', '137covid_patient10_SR_3_IM00017.png', '137covid_patient10_SR_3_IM00020.png', '137covid_patient10_SR_3_IM00025.png', '137covid_patient10_SR_3_IM00026.png', '137covid_patient10_SR_3_IM00028.png', '137covid_patient10_SR_4_IM00059.png', '137covid_patient10_SR_4_IM00060.png', '137covid_patient10_SR_4_IM00061.png', '137covid_patient10_SR_4_IM00067.png', '137covid_patient10_SR_4_IM00068.png', '137covid_patient10_SR_4_IM00069.png', '137covid_patient10_SR_4_IM00070.png', '137covid_patient115_SR_2_IM00011.png', '137covid_patient115_SR_2_IM00012.png', '137covid_patient115_SR_2_IM00013.png', '137covid_patient115_SR_2_IM00014.png', '137covid_patient115_SR_2_IM00015.png', '137covid_patient115_SR_2_IM00016.png', '137covid_patient115_SR_2_IM00017.png', '137covid_patient115_SR_2_IM00018.png', '137covid_patient115_SR_2_IM00019.png', '137covid_patient115_SR_2_IM00020.png', '137covid_patient115_SR_2_IM00021.png', '137covid_patient115_SR_2_IM00022.png', '137covid_patient115_SR_2_IM00023.png', '137covid_patient115_SR_2_IM00024.png', '137covid_patient115_SR_2_IM00025.png', '137covid_patient115_SR_2_IM000 ...

# %%
train_image=[]
for im in train_images:
   if im.endswith('.png'):
    image_path = os.path.join('drive/My Drive/vikii/dc', im)
    img=load_img(image_path,target_size=(64,64),color_mode='grayscale')
    img=img_to_array(img)
    img=img/255
    train_image.append(img)

train_df=np.array(train_image)

# %%
#Subplotting images
def plot_img(dataset):
  f,ax=plt.subplots(1,5)
  f.set_size_inches(40,20)
  for i in range(5,10):
    ax[i-5].imshow(dataset[i].reshape(64,64), cmap='gray')
  plt.show()

  #Overall, this function creates a figure with subplots and plots a subset of images from the dataset on those subplots. The resulting figure will display 5 images in a row, each resized to a 64x64 grayscale image.

# %%
#Adding gaussian noise with 0.05 factor
def add_noise(image):
  row,col,ch=image.shape
  mean=0
  sigma=1
  gauss=np.random.normal(mean,sigma,(row,col,ch))
  gauss=gauss.reshape(row,col,ch)
  noisy=image+gauss*0.05
  return noisy

# %%
noised_df=[]
for img in train_df:
  noisy=add_noise(img)
  noised_df.append(noisy)

noised_df=np.array(noised_df)

# %%
plot_img(train_df)

# %%
plot_img(noised_df)

# %%
xnoised=noised_df[:400]
xtest=noised_df[400:]

# %%
def autoencoder():
  input_img=Input(shape=(64,64,1),name='image_input')
  #enoder
  x = Conv2D(64, (3,3), activation='relu', padding='same', name='Conv1')(input_img)
  x = MaxPooling2D((2,2), padding='same', name='pool1')(x)
  x = Conv2D(64, (3,3), activation='relu', padding='same', name='Conv2')(x)
  x = MaxPooling2D((2,2), padding='same', name='pool2')(x)

  #decoder
  x = Conv2D(64, (3,3), activation='relu', padding='same', name='Conv3')(x)
  x = UpSampling2D((2,2), name='upsample1')(x)
  x = Conv2D(64, (3,3), activation='relu', padding='same', name='Conv4')(x)
  x = UpSampling2D((2,2), name='upsample2')(x)
  x = Conv2D(1, (3,3), activation='sigmoid', padding='same', name='Conv5')(x)

  #model
  autoencoder = Model(inputs=input_img, outputs=x)
  autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

  return autoencoder

# %%
model= autoencoder()
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  image_input (InputLayer)    [(None, 64, 64, 1)]       0
#
#  Conv1 (Conv2D)              (None, 64, 64, 64)        640
#
#  pool1 (MaxPooling2D)        (None, 32, 32, 64)        0
#
#  Conv2 (Conv2D)              (None, 32, 32, 64)        36928
#
#  pool2 (MaxPooling2D)        (None, 16, 16, 64)        0
#
#  Conv3 (Conv2D)              (None, 16, 16, 64)        36928
#
#  upsample1 (UpSampling2D)    (None, 32, 32, 64)        0
#
#  Conv4 (Conv2D)              (None, 32, 32, 64)        36928
#
#  upsample2 (UpSampling2D)    (None, 64, 64, 64)        0
#
#  Conv5 (Conv2D)              (None, 64, 64, 1)         577
#
# =================================================================
# Total params: 112,001
# Trainable params: 112,001
# Non-trainable params: 0
# _________________________________________________________________

# %%
with tf.device('/device:GPU:0'):
    early_stopping = EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=1, mode='auto')
    model.fit(xnoised, xnoised, epochs=50, batch_size=10, validation_data=(xtest, xtest), callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 40/40 [==============================] - 27s 621ms/step - loss: 0.5832 - val_loss: 0.5023
# Epoch 2/50
# 40/40 [==============================] - 31s 786ms/step - loss: 0.5343 - val_loss: 0.4817
# Epoch 3/50
# 40/40 [==============================] - 26s 641ms/step - loss: 0.5257 - val_loss: 0.4781
# Epoch 4/50
# 40/40 [==============================] - 26s 668ms/step - loss: 0.5226 - val_loss: 0.4749
# Epoch 5/50
# 40/40 [==============================] - 26s 666ms/step - loss: 0.5204 - val_loss: 0.4742
# Epoch 6/50
# 40/40 [==============================] - 27s 673ms/step - loss: 0.5187 - val_loss: 0.4717
# Epoch 7/50
# 40/40 [==============================] - 34s 853ms/step - loss: 0.5182 - val_loss: 0.4711
# Epoch 8/50
# 40/40 [==============================] - 26s 670ms/step - loss: 0.5163 - val_loss: 0.4690
# Epoch 9/50
# 40/40 [==============================] - 27s 673ms/step - loss: 0.5151 - val_loss: 0.4667
# Epoch 10/50
# 40/40 [==============================] - 25s 644ms/step - loss: 0.5144 - val_loss: 0.4663
# Epoch 11/50
# 40/40 [==============================] - 33s 821ms/step - loss: 0.5138 - val_loss: 0.4668
# Epoch 12/50
# 40/40 [==============================] - 27s 675ms/step - loss: 0.5130 - val_loss: 0.4658
# Epoch 13/50
# 40/40 [==============================] - 25s 622ms/step - loss: 0.5119 - val_loss: 0.4638
# Epoch 14/50
# 40/40 [==============================] - 27s 669ms/step - loss: 0.5110 - val_loss: 0.4640
# Epoch 15/50
# 40/40 [==============================] - 27s 683ms/step - loss: 0.5102 - val_loss: 0.4626
# Epoch 16/50
# 40/40 [==============================] - 34s 858ms/step - loss: 0.5096 - val_loss: 0.4643
# Epoch 17/50
# 40/40 [==============================] - 26s 663ms/step - loss: 0.5088 - val_loss: 0.4622
# Epoch 18/50
# 40/40 [==============================] - 27s 678ms/step - loss: 0.5084 - val_loss: 0.4622
# Epoch 19/50
# 40/40 [==============================] - 27s 678ms/step - loss: 0.5082 - val_loss: 0.4624
# Epoch 20/50
# 40/40 [==============================] - 27s 680ms/step - loss: 0.5074 - val_loss: 0.4605
# Epoch 21/50
# 40/40 [==============================] - 33s 850ms/step - loss: 0.5070 - val_loss: 0.4606
# Epoch 22/50
# 40/40 [==============================] - 27s 676ms/step - loss: 0.5069 - val_loss: 0.4603
# Epoch 23/50
# 40/40 [==============================] - 27s 674ms/step - loss: 0.5061 - val_loss: 0.4595
# Epoch 24/50
# 40/40 [==============================] - 26s 653ms/step - loss: 0.5061 - val_loss: 0.4598
# Epoch 25/50
# 40/40 [==============================] - 26s 643ms/step - loss: 0.5060 - val_loss: 0.4600
# Epoch 26/50
# 40/40 [==============================] - 27s 679ms/step - loss: 0.5051 - val_loss: 0.4587
# Epoch 27/50
# 40/40 [==============================] - 27s 676ms/step - loss: 0.5049 - val_loss: 0.4585
# Epoch 28/50
# 40/40 [==============================] - 27s 674ms/step - loss: 0.5051 - val_loss: 0.4580
# Epoch 29/50
# 40/40 [==============================] - 34s 856ms/step - loss: 0.5045 - val_loss: 0.4578
# Epoch 30/50
# 40/40 [==============================] - 27s 676ms/step - loss: 0.5042 - val_loss: 0.4592
# Epoch 31/50
# 40/40 [==============================] - 26s 671ms/step - loss: 0.5046 - val_loss: 0.4582
# Epoch 32/50
# 40/40 [==============================] - 26s 665ms/step - loss: 0.5038 - val_loss: 0.4572
# Epoch 33/50
# 40/40 [==============================] - 25s 631ms/step - loss: 0.5035 - val_loss: 0.4577
# Epoch 34/50
# 40/40 [==============================] - 29s 732ms/step - loss: 0.5037 - val_loss: 0.4586
# Epoch 35/50
# 40/40 [==============================] - 27s 674ms/step - loss: 0.5032 - val_loss: 0.4573
# Epoch 36/50
# 40/40 [==============================] - 27s 676ms/step - loss: 0.5034 - val_loss: 0.4568
# Epoch 37/50
# 40/40 [==============================] - 26s 663ms/step - loss: 0.5028 - val_loss: 0.4576
# Epoch 38/50
# 40/40 [==============================] - 25s 636ms/step - loss: 0.5029 - val_loss: 0.4573
# Epoch 39/50
# 40/40 [==============================] - 27s 673ms/step - loss: 0.5026 - val_loss: 0.4570
# Epoch 40/50
# 40/40 [==============================] - 27s 678ms/step - loss: 0.5022 - val_loss: 0.4558
# Epoch 41/50
# 40/40 [==============================] - 27s 674ms/step - loss: 0.5024 - val_loss: 0.4563
# Epoch 42/50
# 40/40 [==============================] - 26s 660ms/step - loss: 0.5022 - val_loss: 0.4569
# Epoch 43/50
# 40/40 [==============================] - 25s 629ms/step - loss: 0.5020 - val_loss: 0.4563
# Epoch 44/50
# 40/40 [==============================] - 27s 675ms/step - loss: 0.5019 - val_loss: 0.4569
# Epoch 45/50
# 40/40 [==============================] - 27s 675ms/step - loss: 0.5020 - val_loss: 0.4568
# Epoch 46/50
# 40/40 [==============================] - 27s 679ms/step - loss: 0.5015 - val_loss: 0.4555
# Epoch 47/50
# 40/40 [==============================] - 27s 675ms/step - loss: 0.5014 - val_loss: 0.4554
# Epoch 48/50
# 40/40 [==============================] - 25s 621ms/step - loss: 0.5013 - val_loss: 0.4575
# Epoch 49/50
# 40/40 [==============================] - 27s 668ms/step - loss: 0.5016 - val_loss: 0.4563
# Epoch 50/50
# 40/40 [==============================] - 27s 678ms/step - loss: 0.5009 - val_loss: 0.4550

# %%
xtrain= train_df[100:]

# %%
pred= model.predict(xtest[:5])
def plot_predictions(y_true, y_pred):
    f, ax = plt.subplots(4, 5)
    f.set_size_inches(10.5,7.5)
    for i in range(5):
        ax[0][i].imshow(np.reshape(xtrain[i], (64,64)), aspect='auto', cmap='gray')
        ax[1][i].imshow(np.reshape(y_true[i], (64,64)), aspect='auto', cmap='gray')
        ax[2][i].imshow(np.reshape(y_pred[i], (64,64)), aspect='auto', cmap='gray')
        ax[3][i].imshow(cv2.medianBlur(xtrain[i], (5)), aspect='auto', cmap='gray')
    plt.tight_layout()
plot_predictions(xtest[:5], pred[:5])
# Out:
# 1/1 [==============================] - 0s 213ms/step

# %%
median_blur = cv2.medianBlur(xtrain[0], (5))
gaussian_blur=cv2.GaussianBlur(xtrain[0],(5,5),0)
average_blur=cv2.blur(xtrain[0],(5,5))
bilateral_filter=cv2.bilateralFilter(xtrain[0],9,75,75)
f,ax=plt.subplots(1,5)
f.set_size_inches(40,20)
ax[0].imshow(pred[0].reshape(64,64), cmap='gray')
ax[0].set_title('Autoencoder Image')
ax[1].imshow(median_blur,cmap='gray')
ax[1].set_title('Median Filter')
ax[2].imshow(gaussian_blur,cmap='gray')
ax[2].set_title('Gaussian Filter')
ax[3].imshow(average_blur,cmap='gray')
ax[3].set_title('Average Filter')
ax[4].imshow(bilateral_filter,cmap='gray')
ax[4].set_title('Bilateral Filter')
# Out:
# Text(0.5, 1.0, 'Bilateral Filter')

# %%
def PSNR(original, denoised):
    mse = np.mean((original - denoised) ** 2)
    if(mse == 0):
        return 100
    max_pixel = 255.0
    psnr = 20 * log10(max_pixel / sqrt(mse))
    return psnr


value1 = PSNR(xtest[0], median_blur)
value2 = PSNR(xtest[0], pred[0])
value3 = PSNR(xtest[0], gaussian_blur)
value4 = PSNR(xtest[0], average_blur)
value5 = PSNR(xtest[0], bilateral_filter)

print("PSNR values")
print(f"Autoencoder Image : {value2} dB")
print(f"Median Filter Image : {value1} dB")
print(f"Gaussian Filter Image : {value3} dB")
print(f"Average Filter Image : {value4} dB")
print(f"Bilateral Filter Image : {value5} dB")
# Out:
# PSNR values
# Autoencoder Image : 68.07156987842633 dB
# Median Filter Image : 55.887701072519064 dB
# Gaussian Filter Image : 56.26786752416934 dB
# Average Filter Image : 56.432927754126894 dB
# Bilateral Filter Image : 56.63935355054526 dB
